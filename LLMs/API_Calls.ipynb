# %%
from dotenv import load_dotenv
load_dotenv()
import os

if os.environ.get("OPENAI_API_KEY"):
    print("OPENAI api key is set")
if os.environ.get("GOOGLE_API_KEY"):
    print("Google api key is set")
# Out:
# OPENAI api key is set

# %% [markdown]
# ### OPENAI SDK

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.4-mini",
    input="Tell me about data domain"
)

print(response.output_text)
# Out:
# “Data domain” can mean a few related things, depending on context:
#
# ## 1) In data management / analytics
# A **data domain** is a specific area or subject that data describes.
#
# Examples:
# - **Customer data domain**: names, addresses, contact info, loyalty status
# - **Product data domain**: SKUs, prices, categories, inventory
# - **Finance data domain**: invoices, payments, budgets, transactions
#
# In this sense, a domain groups data by business meaning and ownership.
#
# ### Why it matters
# - Helps organize data into manageable areas
# - Clarifies who owns and maintains the data
# - Improves data quality and governance
# - Makes integration and reporting easier
#
# ---
#
# ## 2) In databases
# A **domain** can also mean the set of valid values a field can take.
#
# Example:
# - `Age` domain: integers from 0 to 120
# - `CountryCode` domain: valid ISO country codes
# - `Status` domain: {Active, Inactive, Pending}
#
# This is about **data constraints** and **data types**.
#
# ---
#
# ## 3) In data architecture / data mesh
# A **data domain** is often a business-aligned slice of the organization with its own data products and stewardship.
#
# Examples:
# - Sales domain
# - Marketing domain
# - Supply chain domain
#
# Each domain may own its own data pipelines, definitions, and quality standards.
#
# ---
#
# ## Key ideas associated with a data domain
# - **Scope**: what data is included
# - **Ownership**: who is responsible
# - **Definitions**: what the data means
# - **Rules**: valid values, quality checks, privacy controls
# - **Relationships**: how it connects to other domains
#
# ---
#
# ## Simple example
# A retail company might have:
# - **Customer domain**: customer profiles and preferences
# - **Order domain**: purchases and order status
# - **Inventory domain**: stock levels and warehouse data
# - **Payment domain**: charges, refunds, and transactions
#
# Each domain has its own purpose, but they connect to support the business.
#
# If you want, I can also explain:
# - **data domain in data governance**
# - **data domain vs data model**
# - **data domain in data mesh**

# %% [markdown]
# ### GEMINI SDK

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 4
#       1 from google import genai
#       2
#       3 # The client gets the API key from the environment variable `GEMINI_API_KEY`.
# ----> 4 client = genai.Client()
#       5
#       6 response = client.models.generate_content(
#       7     model="gemini-3-flash-preview", contents="Explain how AI works in a few words"
#
# File ~/Project/AI_fundamentals/.venv/lib/python3.14/site-packages/google/genai/client.py:427, in Client.__init__(self, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     424   else:
#     425     http_options = HttpOptions(base_url=base_url)
# --> 427 self._api_client = self._get_api_client(
#     428     vertexai=vertexai,
#     429     api_key=api_key,
#     430     credentials=credentials,
#     431     project=project,
#     432     location=location,
#     433     debug_config=self._debug_config,
#     434     http_options=http_options,
#     435 )
#     437 self._aio = AsyncClient(self._api_client)
#     438 self._models = Models(self._api_client)
#
# File ~/Project/AI_fundamentals/.venv/lib/python3.14/site-packages/google/genai/client.py:475, in Client._get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     458 if debug_config and debug_config.client_mode in [
#     459     'record',
#     460     'replay',
#     461     'auto',
#     462 ]:
#     463   return ReplayApiClient(
#     464       mode=debug_config.client_mode,  # type: ignore[arg-type]
#     465       replay_id=debug_config.replay_id,  # type: ignore[arg-type]
#    (...)    472       http_options=http_options,
#     473   )
# --> 475 return BaseApiClient(
#     476     vertexai=vertexai,
#     477     api_key=api_key,
#     478     credentials=credentials,
#     479     project=project,
#     480     location=location,
#     481     http_options=http_options,
#     482 )
#
# File ~/Project/AI_fundamentals/.venv/lib/python3.14/site-packages/google/genai/_api_client.py:732, in BaseApiClient.__init__(self, vertexai, api_key, credentials, project, location, http_options)
#     730 else:  # Implicit initialization or missing arguments.
#     731   if not self.api_key:
# --> 732     raise ValueError(
#     733         'No API key was provided. Please pass a valid API key. Learn how to'
#     734         ' create an API key at'
#     735         ' https://ai.google.dev/gemini-api/docs/api-key.'
#     736     )
#     737   self._http_options.base_url = 'https://generativelanguage.googleapis.com/'
#     738   self._http_options.api_version = 'v1beta'
#
# ValueError: No API key was provided. Please pass a valid API key. Learn how to create an API key at https://ai.google.dev/gemini-api/docs/api-key.
