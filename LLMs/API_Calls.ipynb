# %%
from dotenv import load_dotenv
load_dotenv()
import os

if os.environ.get("OPENAI_API_KEY"):
    print("OPENAI api key is set")
if os.environ.get("GOOGLE_API_KEY"):
    print("Google api key is set")
# Out:
# OPENAI api key is set

# %%
# OpenAI SDK - Making API calls to OpenAI models
# The client is initialized in the cell below and can be used for various tasks

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.4-mini",
    input="Tell me about data domain"
)

print(response.output_text)
# Out:
# “Data domain” can mean a few related things depending on context, but in general it refers to a specific area of business or subject matter that data describes.
#
# ## Simple definition
# A **data domain** is a collection of data that belongs to the same topic or part of an organization.
#
# Examples:
# - **Customer data domain**: names, addresses, contact info, preferences
# - **Product data domain**: product IDs, descriptions, prices, inventory
# - **Finance data domain**: invoices, payments, budgets, ledgers
# - **HR data domain**: employees, roles, salaries, benefits
#
# ## Why it matters
# Organizing data into domains helps with:
# - **Ownership**: deciding who is responsible for the data
# - **Governance**: setting rules for quality, security, and access
# - **Consistency**: using the same definitions across systems
# - **Scalability**: making large data environments easier to manage
#
# ## In data architecture
# In enterprise data management, domains are often used to structure data by business area. For example:
# - Sales domain
# - Marketing domain
# - Operations domain
# - Supply chain domain
#
# Each domain may have its own databases, data products, or data pipelines.
#
# ## In data modeling / semantics
# Sometimes “data domain” means the set of valid values a field can take.
#
# Example:
# - For a field called `Country`, the domain might be all valid country names or codes.
# - For `Age`, the domain might be integers from 0 to 120.
#
# ## In data warehouse / analytics contexts
# A data domain can also refer to a subject area in a warehouse or lakehouse, such as:
# - Customer analytics
# - Sales analytics
# - Web traffic analytics
#
# If you want, I can also explain:
# 1. **data domain in enterprise architecture**,
# 2. **data domain in databases/data modeling**, or
# 3. **domain-driven design and data domains**.
