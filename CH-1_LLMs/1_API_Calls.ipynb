# %%
from dotenv import load_dotenv
load_dotenv()
import os

if os.environ.get("OPENAI_API_KEY"):
    print("OPENAI api key is set")
if os.environ.get("GOOGLE_API_KEY"):
    print("Google api key is set")
# Out:
# OPENAI api key is set

# %% [markdown]
# # OpenAI API

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.4-mini",
    input="Tell me about open ai"
)

print(response.output_text)
# Out:
# OpenAI is an artificial intelligence research and product company known for creating advanced AI systems and making them available to the public through products and APIs.
#
# A quick overview:
#
# - **Founded:** 2015
# - **Mission:** To build AI that benefits humanity
# - **Known for:** ChatGPT, GPT models, DALL·E, Whisper, and AI APIs
# - **What it does:**
#   - Develops large language models that can generate and understand text
#   - Builds tools for image generation, speech recognition, and other AI tasks
#   - Offers developer APIs so apps can use AI capabilities
#
# Some major OpenAI products:
# - **ChatGPT:** A conversational AI assistant
# - **GPT models:** Language models for writing, coding, summarizing, and reasoning
# - **DALL·E:** AI image generation
# - **Whisper:** Speech-to-text
# - **API platform:** Lets developers integrate AI into software
#
# If you want, I can also give you:
# 1. a **simple beginner explanation**,
# 2. a **history of OpenAI**, or
# 3. a **list of OpenAI products and what they do**.

# %% [markdown]
# # Gemini API

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents="Explain how AI works in a few words"
)
print(response.text)
