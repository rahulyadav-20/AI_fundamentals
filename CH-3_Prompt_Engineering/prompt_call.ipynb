# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()

llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)
# Out:
# /Users/rahulyadav/Project/AI_fundamentals/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %% [markdown]
# ### Zero-Shot Prompting

# %%
llm.invoke("Translate the following English sentence to French: 'How are you?'")
# Out:
# AIMessage(content='Comment vas-tu ?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5, 'prompt_tokens': 20, 'total_tokens': 25, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DUmqX4VvSHp3DImsDvAUCc6L6JIpn', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d8f8e-889d-78a2-8fb6-b241ce5a2beb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 5, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ### One-Shot Prompting

# %%
one_shot_prompt = (
    "Translate the following English sentence to French.\n"
    "Example: 'Good morning' -> 'Bonjour'\n"
    "Now, translate: 'How are you?'"
)
llm.invoke(one_shot_prompt)
# Out:
# AIMessage(content='Comment vas-tu ?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5, 'prompt_tokens': 34, 'total_tokens': 39, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DUmqugN2mI2SeJvOzO75q4EnAJEDW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d8f8e-e53e-71a0-81d5-1ae39b66b368-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 34, 'output_tokens': 5, 'total_tokens': 39, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ### Few-Shot Prompting

# %%
few_shot_prompt = (
    "Translate the following English sentences to French.\n"
    "Example 1: 'Good morning' -> 'Bonjour'\n"
    "Example 2: 'Thank you' -> 'Merci'\n"
    "Now, translate: 'How are you?'"
)
llm.invoke(few_shot_prompt)
# Out:
# AIMessage(content='Comment vas-tu ?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5, 'prompt_tokens': 49, 'total_tokens': 54, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DUmrWiFDZ54ZPFgqBwl6jk4GsVMRd', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d8f8f-78e7-7552-85c5-4976e8277cb1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 49, 'output_tokens': 5, 'total_tokens': 54, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ### Chain-of-Thought Prompting

# %%
cot_prompt = (
    "Solve the following math problem step by step.\n"
    "Question: If you have 10 apples and get 20 more, how many apples do you have?\n"
    "Example:\n"
    "Question: If you have 3 apples and get 2 more, how many apples do you have?\n"
    "Let's think step by step.\n"
    "Step 1: Start with 3 apples.\n"
    "Step 2: Get 2 more apples.\n"
    "Step 3: 3 + 2 = 5.\n"
    "Answer: 5 apples."
)
llm.invoke(cot_prompt)
# Out:
# AIMessage(content="Now let's solve the original problem step by step.\nStep 1: Start with 10 apples.\nStep 2: Get 20 more apples.\nStep 3: 10 + 20 = 30.\nAnswer: You will have 30 apples.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 107, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DUmrw6Y1wSVGFoZiQg5Mu1AkBlgWQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d8f8f-db21-7ee3-9f84-0faa91ee230f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 53, 'total_tokens': 160, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'au
# ...
